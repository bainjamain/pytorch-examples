# %% [markdown]
# # Generative Adversarial Network (GAN)

# %%
import torch
import torchvision
import torch.nn as nn
from torch.autograd import Variable

cuda = torch.cuda.is_available() # True if cuda is available, False otherwise

import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# Let's load the MNIST data set.

# %%
transform = torchvision.transforms.Compose([torchvision.transforms.ToTensor(),
                                torchvision.transforms.Normalize(mean=(.5, .5, .5), std=(.5, .5, .5))])
mnist = torchvision.datasets.MNIST(root='../data/', train=True, transform=transform, download=True)

# %% [markdown]
# We define some hyperparameters.

# %%
batch =  100

# Discriminator
input_size_d = 28 * 28
hidden_size_d = 256
output_size_d = 1 # probability
learning_rate_d = .0005

# Generator
input_size_g = 128
hidden_size_g = 256
output_size_g = input_size_d # output of generator is a flatten image
learning_rate_g = .0005

epochs = 150

# %% [markdown]
# Create a *loader* to feed the data batch by batch during training.

# %%
data_loader = torch.utils.data.DataLoader(mnist, batch_size=batch, shuffle=True)

# %% [markdown]
# Now, we define the architectures of the **discriminator** and **generator**.

# %%
discriminator = nn.Sequential(
            nn.Linear(input_size_d, hidden_size_d),
            nn.ReLU(),
            nn.Linear(hidden_size_d, hidden_size_d),
            nn.ReLU(),
            nn.Linear(hidden_size_d, output_size_d),
            nn.Sigmoid())

generator = nn.Sequential(
            nn.Linear(input_size_g, hidden_size_g),
            nn.LeakyReLU(),
            nn.Linear(hidden_size_g, hidden_size_g),
            nn.LeakyReLU(),
            nn.Linear(hidden_size_g, output_size_g),
            nn.Tanh())

discriminator = discriminator.cuda() if cuda else disciminator
generator = generator.cuda() if cuda else generator

# %% [markdown]
# We define the loss function and the optimization schemes (here **Adam**) for both the discriminator and the generator.

# %%
criterion = nn.BCELoss()
optimizer_discriminator = torch.optim.Adam(params=discriminator.parameters(), lr=learning_rate_d)
optimizer_generator = torch.optim.Adam(params=generator.parameters(), lr=learning_rate_g)

# %% [markdown]
# Finally, we train the discriminator and the generator together.

# %%
data_size = int(mnist.train_labels.size()[0])

d_x = 0. # average classification probabilities of real data
d_g_z = 0. # average classification probabilities of fake data
loss_d = 0. # average loss of discriminator
loss_g = 0. # average loss of generator

for i in range(epochs):
    for j, (images, _) in enumerate(data_loader):
        # map tensor from (batch, 1, 28, 28) to (batch, 28 * 28)
        images = images.view(images.size(0), -1)
        real_images = Variable(images).cuda() if cuda else Variable(images)
        
        ones = Variable(torch.ones(images.size(0))).cuda() if cuda else Variable(torch.ones(images.size(0)))
        zeros = Variable(torch.zeros(images.size(0))).cuda() if cuda else Variable(torch.zeros(images.size(0)))
        
        # ******************
        # Discriminator step
        # ******************
        discriminator.zero_grad()
        
        noise = Variable(torch.randn(batch, input_size_g)).cuda() if cuda else Variable(torch.randn(batch, input_size_g))
        fake_images = generator(noise) # map input noise to the data space (image)
        discriminator_real = discriminator(real_images)
        discriminator_fake = discriminator(fake_images.detach())
        real_loss_discriminator = criterion(discriminator_real, ones)
        fake_loss_discriminator = criterion(discriminator_fake, zeros)
        
        loss_discriminator = real_loss_discriminator + fake_loss_discriminator
        loss_discriminator.backward()
        optimizer_discriminator.step()
        
        
        # ******************
        # * Generator step *
        # ******************
        generator.zero_grad()
        
        noise = Variable(torch.randn(batch, input_size_g)).cuda() if cuda else Variable(torch.randn(batch, input_size_g))
        fake_images = generator(noise) # map input noise to the data space (image)
        discriminator_fake2 = discriminator(fake_images)
        loss_generator = criterion(discriminator_fake2, ones)
        loss_generator.backward()
        optimizer_generator.step()
        
        d_x += torch.sum(discriminator_real).data[0] / data_size
        d_g_z += torch.sum(discriminator_fake).data[0] / data_size
        loss_d += loss_discriminator.data[0] / (data_size / batch)
        loss_g += loss_generator.data[0] / (data_size / batch)
        

    print('Epoch %i/%i, d_loss: %.2f, g_loss: %.2f, D(X)=%.2f D(G(Z))=%.2f' % 
                (i + 1, epochs, loss_d,
                loss_g, d_x, d_g_z))    
    d_x, d_g_z, loss_d, loss_g = 0., 0., 0., 0.
# Out:
# Epoch 1/150, d_loss: 0.41, g_loss: 4.08, D(X)=0.92 D(G(Z))=0.18
# Epoch 2/150, d_loss: 1.16, g_loss: 3.62, D(X)=0.75 D(G(Z))=0.29
# Epoch 3/150, d_loss: 0.86, g_loss: 2.31, D(X)=0.78 D(G(Z))=0.26
# Epoch 4/150, d_loss: 1.28, g_loss: 2.07, D(X)=0.67 D(G(Z))=0.37
# Epoch 5/150, d_loss: 1.04, g_loss: 1.63, D(X)=0.69 D(G(Z))=0.34
# Epoch 6/150, d_loss: 0.88, g_loss: 2.41, D(X)=0.76 D(G(Z))=0.26
# Epoch 7/150, d_loss: 0.95, g_loss: 2.16, D(X)=0.73 D(G(Z))=0.29
# Epoch 8/150, d_loss: 0.89, g_loss: 2.11, D(X)=0.74 D(G(Z))=0.28
# Epoch 9/150, d_loss: 0.96, g_loss: 1.81, D(X)=0.71 D(G(Z))=0.30
# Epoch 10/150, d_loss: 0.89, g_loss: 2.16, D(X)=0.74 D(G(Z))=0.27
# Epoch 11/150, d_loss: 0.77, g_loss: 2.59, D(X)=0.79 D(G(Z))=0.23
# Epoch 12/150, d_loss: 0.76, g_loss: 2.66, D(X)=0.79 D(G(Z))=0.23
# Epoch 13/150, d_loss: 0.77, g_loss: 2.66, D(X)=0.77 D(G(Z))=0.24
# Epoch 14/150, d_loss: 0.89, g_loss: 2.26, D(X)=0.75 D(G(Z))=0.27
# Epoch 15/150, d_loss: 0.90, g_loss: 1.95, D(X)=0.73 D(G(Z))=0.28
# Epoch 16/150, d_loss: 0.88, g_loss: 2.05, D(X)=0.73 D(G(Z))=0.28
# Epoch 17/150, d_loss: 0.77, g_loss: 2.63, D(X)=0.78 D(G(Z))=0.23
# Epoch 18/150, d_loss: 0.78, g_loss: 2.60, D(X)=0.78 D(G(Z))=0.23
# Epoch 19/150, d_loss: 0.79, g_loss: 2.77, D(X)=0.78 D(G(Z))=0.23
# Epoch 20/150, d_loss: 0.83, g_loss: 2.14, D(X)=0.75 D(G(Z))=0.26
# Epoch 21/150, d_loss: 0.85, g_loss: 2.66, D(X)=0.77 D(G(Z))=0.24
# Epoch 22/150, d_loss: 0.83, g_loss: 2.29, D(X)=0.76 D(G(Z))=0.25
# Epoch 23/150, d_loss: 0.82, g_loss: 2.17, D(X)=0.75 D(G(Z))=0.26
# Epoch 24/150, d_loss: 0.79, g_loss: 2.09, D(X)=0.75 D(G(Z))=0.25
# Epoch 25/150, d_loss: 0.79, g_loss: 2.17, D(X)=0.76 D(G(Z))=0.25
# Epoch 26/150, d_loss: 0.71, g_loss: 2.18, D(X)=0.78 D(G(Z))=0.23
# Epoch 27/150, d_loss: 0.81, g_loss: 2.39, D(X)=0.77 D(G(Z))=0.24
# Epoch 28/150, d_loss: 0.81, g_loss: 2.50, D(X)=0.77 D(G(Z))=0.24
# Epoch 29/150, d_loss: 0.76, g_loss: 2.03, D(X)=0.76 D(G(Z))=0.24
# Epoch 30/150, d_loss: 0.72, g_loss: 1.93, D(X)=0.77 D(G(Z))=0.24
# Epoch 31/150, d_loss: 0.73, g_loss: 2.15, D(X)=0.78 D(G(Z))=0.23
# Epoch 32/150, d_loss: 0.78, g_loss: 2.41, D(X)=0.77 D(G(Z))=0.23
# Epoch 33/150, d_loss: 0.80, g_loss: 1.93, D(X)=0.75 D(G(Z))=0.26
# Epoch 34/150, d_loss: 0.80, g_loss: 1.88, D(X)=0.75 D(G(Z))=0.26
# Epoch 35/150, d_loss: 0.84, g_loss: 1.94, D(X)=0.74 D(G(Z))=0.27
# Epoch 36/150, d_loss: 0.80, g_loss: 1.89, D(X)=0.74 D(G(Z))=0.26
# Epoch 37/150, d_loss: 0.83, g_loss: 2.08, D(X)=0.75 D(G(Z))=0.26
# Epoch 38/150, d_loss: 0.82, g_loss: 1.95, D(X)=0.74 D(G(Z))=0.26
# Epoch 39/150, d_loss: 0.85, g_loss: 1.86, D(X)=0.74 D(G(Z))=0.27
# Epoch 40/150, d_loss: 0.87, g_loss: 1.75, D(X)=0.72 D(G(Z))=0.28
# Epoch 41/150, d_loss: 0.89, g_loss: 1.73, D(X)=0.72 D(G(Z))=0.29
# Epoch 42/150, d_loss: 0.91, g_loss: 1.67, D(X)=0.71 D(G(Z))=0.30
# Epoch 43/150, d_loss: 0.91, g_loss: 1.61, D(X)=0.71 D(G(Z))=0.30
# Epoch 44/150, d_loss: 0.89, g_loss: 1.70, D(X)=0.71 D(G(Z))=0.29
# Epoch 45/150, d_loss: 0.90, g_loss: 1.63, D(X)=0.71 D(G(Z))=0.30
# Epoch 46/150, d_loss: 0.92, g_loss: 1.61, D(X)=0.70 D(G(Z))=0.30
# Epoch 47/150, d_loss: 0.91, g_loss: 1.61, D(X)=0.71 D(G(Z))=0.30
# Epoch 48/150, d_loss: 0.91, g_loss: 1.60, D(X)=0.71 D(G(Z))=0.31
# Epoch 49/150, d_loss: 0.91, g_loss: 1.56, D(X)=0.70 D(G(Z))=0.31
# Epoch 50/150, d_loss: 0.94, g_loss: 1.59, D(X)=0.70 D(G(Z))=0.31
# Epoch 51/150, d_loss: 0.93, g_loss: 1.54, D(X)=0.70 D(G(Z))=0.31
# Epoch 52/150, d_loss: 0.94, g_loss: 1.54, D(X)=0.69 D(G(Z))=0.31
# Epoch 53/150, d_loss: 0.97, g_loss: 1.49, D(X)=0.68 D(G(Z))=0.33
# Epoch 54/150, d_loss: 0.95, g_loss: 1.47, D(X)=0.69 D(G(Z))=0.32
# Epoch 55/150, d_loss: 0.98, g_loss: 1.45, D(X)=0.68 D(G(Z))=0.33
# Epoch 56/150, d_loss: 0.99, g_loss: 1.42, D(X)=0.68 D(G(Z))=0.33
# Epoch 57/150, d_loss: 0.98, g_loss: 1.48, D(X)=0.68 D(G(Z))=0.33
# Epoch 58/150, d_loss: 0.99, g_loss: 1.43, D(X)=0.68 D(G(Z))=0.33
# Epoch 59/150, d_loss: 0.98, g_loss: 1.44, D(X)=0.68 D(G(Z))=0.33
# Epoch 60/150, d_loss: 1.00, g_loss: 1.40, D(X)=0.67 D(G(Z))=0.34
# Epoch 61/150, d_loss: 1.01, g_loss: 1.40, D(X)=0.67 D(G(Z))=0.34
# Epoch 62/150, d_loss: 1.01, g_loss: 1.38, D(X)=0.67 D(G(Z))=0.34
# Epoch 63/150, d_loss: 1.02, g_loss: 1.35, D(X)=0.66 D(G(Z))=0.35
# Epoch 64/150, d_loss: 1.03, g_loss: 1.35, D(X)=0.66 D(G(Z))=0.35
# Epoch 65/150, d_loss: 1.04, g_loss: 1.36, D(X)=0.66 D(G(Z))=0.35
# Epoch 66/150, d_loss: 1.06, g_loss: 1.29, D(X)=0.65 D(G(Z))=0.36
# Epoch 67/150, d_loss: 1.05, g_loss: 1.30, D(X)=0.65 D(G(Z))=0.35
# Epoch 68/150, d_loss: 1.06, g_loss: 1.31, D(X)=0.65 D(G(Z))=0.36
# Epoch 69/150, d_loss: 1.05, g_loss: 1.31, D(X)=0.65 D(G(Z))=0.36
# Epoch 70/150, d_loss: 1.07, g_loss: 1.26, D(X)=0.64 D(G(Z))=0.36
# Epoch 71/150, d_loss: 1.06, g_loss: 1.25, D(X)=0.64 D(G(Z))=0.36
# Epoch 72/150, d_loss: 1.08, g_loss: 1.25, D(X)=0.64 D(G(Z))=0.37
# Epoch 73/150, d_loss: 1.07, g_loss: 1.29, D(X)=0.64 D(G(Z))=0.36
# Epoch 74/150, d_loss: 1.08, g_loss: 1.25, D(X)=0.64 D(G(Z))=0.37
# Epoch 75/150, d_loss: 1.08, g_loss: 1.21, D(X)=0.64 D(G(Z))=0.37
# Epoch 76/150, d_loss: 1.07, g_loss: 1.27, D(X)=0.64 D(G(Z))=0.36
# Epoch 77/150, d_loss: 1.08, g_loss: 1.25, D(X)=0.64 D(G(Z))=0.37
# Epoch 78/150, d_loss: 1.09, g_loss: 1.24, D(X)=0.64 D(G(Z))=0.37
# Epoch 79/150, d_loss: 1.09, g_loss: 1.21, D(X)=0.63 D(G(Z))=0.37
# Epoch 80/150, d_loss: 1.09, g_loss: 1.24, D(X)=0.63 D(G(Z))=0.37
# Epoch 81/150, d_loss: 1.09, g_loss: 1.24, D(X)=0.64 D(G(Z))=0.37
# Epoch 82/150, d_loss: 1.10, g_loss: 1.20, D(X)=0.63 D(G(Z))=0.38
# Epoch 83/150, d_loss: 1.10, g_loss: 1.20, D(X)=0.63 D(G(Z))=0.37
# Epoch 84/150, d_loss: 1.10, g_loss: 1.21, D(X)=0.63 D(G(Z))=0.38
# Epoch 85/150, d_loss: 1.11, g_loss: 1.21, D(X)=0.63 D(G(Z))=0.38
# Epoch 86/150, d_loss: 1.10, g_loss: 1.23, D(X)=0.63 D(G(Z))=0.37
# Epoch 87/150, d_loss: 1.11, g_loss: 1.19, D(X)=0.63 D(G(Z))=0.38
# Epoch 88/150, d_loss: 1.12, g_loss: 1.18, D(X)=0.62 D(G(Z))=0.38
# Epoch 89/150, d_loss: 1.11, g_loss: 1.17, D(X)=0.63 D(G(Z))=0.38
# Epoch 90/150, d_loss: 1.11, g_loss: 1.20, D(X)=0.63 D(G(Z))=0.38
# Epoch 91/150, d_loss: 1.12, g_loss: 1.18, D(X)=0.62 D(G(Z))=0.38
# Epoch 92/150, d_loss: 1.11, g_loss: 1.18, D(X)=0.63 D(G(Z))=0.38
# Epoch 93/150, d_loss: 1.11, g_loss: 1.18, D(X)=0.62 D(G(Z))=0.38
# Epoch 94/150, d_loss: 1.11, g_loss: 1.18, D(X)=0.63 D(G(Z))=0.38
# Epoch 95/150, d_loss: 1.12, g_loss: 1.20, D(X)=0.62 D(G(Z))=0.38
# Epoch 96/150, d_loss: 1.12, g_loss: 1.19, D(X)=0.62 D(G(Z))=0.38
# Epoch 97/150, d_loss: 1.12, g_loss: 1.16, D(X)=0.62 D(G(Z))=0.38
# Epoch 98/150, d_loss: 1.12, g_loss: 1.18, D(X)=0.62 D(G(Z))=0.38
# Epoch 99/150, d_loss: 1.13, g_loss: 1.17, D(X)=0.62 D(G(Z))=0.38
# Epoch 100/150, d_loss: 1.13, g_loss: 1.17, D(X)=0.62 D(G(Z))=0.39
# Epoch 101/150, d_loss: 1.12, g_loss: 1.17, D(X)=0.62 D(G(Z))=0.38
# Epoch 102/150, d_loss: 1.12, g_loss: 1.16, D(X)=0.62 D(G(Z))=0.38
# Epoch 103/150, d_loss: 1.12, g_loss: 1.16, D(X)=0.62 D(G(Z))=0.38
# Epoch 104/150, d_loss: 1.13, g_loss: 1.17, D(X)=0.62 D(G(Z))=0.38
# Epoch 105/150, d_loss: 1.13, g_loss: 1.15, D(X)=0.62 D(G(Z))=0.39
# Epoch 106/150, d_loss: 1.13, g_loss: 1.15, D(X)=0.62 D(G(Z))=0.39
# Epoch 107/150, d_loss: 1.13, g_loss: 1.13, D(X)=0.62 D(G(Z))=0.39
# Epoch 108/150, d_loss: 1.14, g_loss: 1.14, D(X)=0.62 D(G(Z))=0.39
# Epoch 109/150, d_loss: 1.13, g_loss: 1.16, D(X)=0.62 D(G(Z))=0.39
# Epoch 110/150, d_loss: 1.14, g_loss: 1.13, D(X)=0.61 D(G(Z))=0.39
# Epoch 111/150, d_loss: 1.13, g_loss: 1.15, D(X)=0.62 D(G(Z))=0.39
# Epoch 112/150, d_loss: 1.14, g_loss: 1.13, D(X)=0.61 D(G(Z))=0.39
# Epoch 113/150, d_loss: 1.14, g_loss: 1.13, D(X)=0.61 D(G(Z))=0.39
# Epoch 114/150, d_loss: 1.14, g_loss: 1.14, D(X)=0.61 D(G(Z))=0.39
# Epoch 115/150, d_loss: 1.14, g_loss: 1.14, D(X)=0.61 D(G(Z))=0.39
# Epoch 116/150, d_loss: 1.15, g_loss: 1.12, D(X)=0.61 D(G(Z))=0.39
# Epoch 117/150, d_loss: 1.14, g_loss: 1.14, D(X)=0.61 D(G(Z))=0.39
# Epoch 118/150, d_loss: 1.14, g_loss: 1.13, D(X)=0.61 D(G(Z))=0.39
# Epoch 119/150, d_loss: 1.15, g_loss: 1.13, D(X)=0.61 D(G(Z))=0.39
# Epoch 120/150, d_loss: 1.14, g_loss: 1.13, D(X)=0.61 D(G(Z))=0.39
# Epoch 121/150, d_loss: 1.15, g_loss: 1.13, D(X)=0.61 D(G(Z))=0.39
# Epoch 122/150, d_loss: 1.15, g_loss: 1.13, D(X)=0.61 D(G(Z))=0.39
# Epoch 123/150, d_loss: 1.15, g_loss: 1.13, D(X)=0.61 D(G(Z))=0.39
# Epoch 124/150, d_loss: 1.15, g_loss: 1.13, D(X)=0.61 D(G(Z))=0.39
# Epoch 125/150, d_loss: 1.15, g_loss: 1.12, D(X)=0.61 D(G(Z))=0.39
# Epoch 126/150, d_loss: 1.15, g_loss: 1.11, D(X)=0.61 D(G(Z))=0.39
# Epoch 127/150, d_loss: 1.15, g_loss: 1.14, D(X)=0.61 D(G(Z))=0.39
# Epoch 128/150, d_loss: 1.15, g_loss: 1.10, D(X)=0.61 D(G(Z))=0.39
# Epoch 129/150, d_loss: 1.15, g_loss: 1.12, D(X)=0.61 D(G(Z))=0.39
# Epoch 130/150, d_loss: 1.15, g_loss: 1.13, D(X)=0.61 D(G(Z))=0.39
# Epoch 131/150, d_loss: 1.15, g_loss: 1.11, D(X)=0.61 D(G(Z))=0.39
# Epoch 132/150, d_loss: 1.15, g_loss: 1.12, D(X)=0.61 D(G(Z))=0.39
# Epoch 133/150, d_loss: 1.15, g_loss: 1.11, D(X)=0.61 D(G(Z))=0.39
# Epoch 134/150, d_loss: 1.15, g_loss: 1.11, D(X)=0.61 D(G(Z))=0.39
# Epoch 135/150, d_loss: 1.15, g_loss: 1.10, D(X)=0.61 D(G(Z))=0.40
# Epoch 136/150, d_loss: 1.15, g_loss: 1.13, D(X)=0.61 D(G(Z))=0.39
# Epoch 137/150, d_loss: 1.16, g_loss: 1.11, D(X)=0.61 D(G(Z))=0.40
# Epoch 138/150, d_loss: 1.15, g_loss: 1.10, D(X)=0.61 D(G(Z))=0.39
# Epoch 139/150, d_loss: 1.15, g_loss: 1.11, D(X)=0.61 D(G(Z))=0.39
# Epoch 140/150, d_loss: 1.16, g_loss: 1.11, D(X)=0.61 D(G(Z))=0.40
# Epoch 141/150, d_loss: 1.16, g_loss: 1.11, D(X)=0.61 D(G(Z))=0.40
# Epoch 142/150, d_loss: 1.15, g_loss: 1.10, D(X)=0.61 D(G(Z))=0.39
# Epoch 143/150, d_loss: 1.15, g_loss: 1.11, D(X)=0.61 D(G(Z))=0.39
# Epoch 144/150, d_loss: 1.16, g_loss: 1.10, D(X)=0.60 D(G(Z))=0.40
# Epoch 145/150, d_loss: 1.16, g_loss: 1.11, D(X)=0.61 D(G(Z))=0.40
# Epoch 146/150, d_loss: 1.16, g_loss: 1.10, D(X)=0.61 D(G(Z))=0.40
# Epoch 147/150, d_loss: 1.16, g_loss: 1.10, D(X)=0.60 D(G(Z))=0.40
# Epoch 148/150, d_loss: 1.17, g_loss: 1.10, D(X)=0.60 D(G(Z))=0.40
# Epoch 149/150, d_loss: 1.16, g_loss: 1.10, D(X)=0.60 D(G(Z))=0.40
# Epoch 150/150, d_loss: 1.17, g_loss: 1.08, D(X)=0.60 D(G(Z))=0.40

# %% [markdown]
# Let's plot some generated images.

# %%
fake_images = fake_images.view(batch, 28, 28).data.cpu().numpy()

fig = plt.figure(figsize=(6, 6))
for i in range(100):
    a = fig.add_subplot(10, 10, i + 1)
    a.axis('off')
    fake_image = fake_images[i - 1]
    a.imshow(fake_image, cmap='Greys_r')
